# %%
import pandas as pd
import numpy as np
happiness = pd.read_csv('d:/dataset/2015.csv')
happiness.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# # grouping

# %%
g =happiness.groupby('Country')

# %%
g

# %%
for country,city_df in g:  # city_df is provided by dataframe for city indexing
    print(country)
    print(city_df)Country
# Out:
# Afghanistan
#          Country         Region  Happiness Rank  Happiness Score  \
# 152  Afghanistan  Southern Asia             153            3.575
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 152         0.03084                   0.31982  0.30285
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 152                   0.30335  0.23414                        0.09719
#
#      Generosity  Dystopia Residual
# 152      0.3651             1.9521
# Albania
#     Country                      Region  Happiness Rank  Happiness Score  \
# 94  Albania  Central and Eastern Europe              95            4.959
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 94         0.05013                   0.87867  0.80434
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 94                   0.81325  0.35733                        0.06413
#
#     Generosity  Dystopia Residual
# 94     0.14272            1.89894
# ...

# %%
for country,city_df in g: 
    print(country)
# Out:
# Afghanistan
# Albania
# Algeria
# Angola
# Argentina
# Armenia
# Australia
# Austria
# Azerbaijan
# Bahrain
# Bangladesh
# Belarus
# Belgium
# Benin
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Brazil
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia
# Cameroon
# Canada
# Central African Republic
# Chad
# Chile
# China
# Colombia
# Comoros
# Congo (Brazzaville)
# Congo (Kinshasa)
# Costa Rica
# Croatia
# Cyprus
# Czech Republic
# Denmark
# Djibouti
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Estonia
# Ethiopia
# Finland
# France
# Gabon
# Georgia
# Germany
# Ghana
# Greece
# Guatemala
# Guinea
# Haiti
# Honduras
# Hong Kong
# Hungary
# Iceland
# India
# Indonesia
# Iran
# Iraq
# Ireland
# Israel
# Italy
# Ivory Coast
# Jamaica
# Japan
# Jordan
# Kazakhstan
# Kenya
# Kosovo
# Kuwait
# Kyrgyzstan
# Laos
# Latvia
# Lebanon
# Lesotho
# Liberia
# Libya
# Lithuania
# Luxembourg
# Macedonia
# Madagascar
# Malawi
# Malaysia
# Mali
# Malta
# Mauritania
# Mauritius
# ...

# %%
g.get_group('Nigeria')
# Out:
#     Country              Region  Happiness Rank  Happiness Score  \
# 77  Nigeria  Sub-Saharan Africa              78            5.268
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 77         0.04192                   0.65435  0.90432
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 77                   0.16007  0.34334                         0.0403
#
#     Generosity  Dystopia Residual
# 77     0.27233            2.89319

# %%
g.get_group('Canada')
# Out:
#   Country         Region  Happiness Rank  Happiness Score  Standard Error  \
# 4  Canada  North America               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 4                        0.32957     0.45811            2.45176

# %%
g.max()
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Afghanistan                    Southern Asia             153            3.575
# Albania           Central and Eastern Europe              95            4.959
# Algeria      Middle East and Northern Africa              68            5.605
# Angola                    Sub-Saharan Africa             137            4.033
# Argentina        Latin America and Caribbean              30            6.574
# ...                                      ...             ...              ...
# Venezuela        Latin America and Caribbean              23            6.810
# Vietnam                    Southeastern Asia              75            5.360
# Yemen        Middle East and Northern Africa             136            4.077
# Zambia                    Sub-Saharan Africa              85            5.129
# Zimbabwe                  Sub-Saharan Africa             115            4.610
#
# ...

# %%
g.mean()
# Out:
#              Happiness Rank  Happiness Score  Standard Error  \
# Country
# Afghanistan             153            3.575         0.03084
# Albania                  95            4.959         0.05013
# Algeria                  68            5.605         0.05099
# Angola                  137            4.033         0.04758
# Argentina                30            6.574         0.04612
# ...                     ...              ...             ...
# Venezuela                23            6.810         0.06476
# Vietnam                  75            5.360         0.03107
# Yemen                   136            4.077         0.04367
# Zambia                   85            5.129         0.06988
# Zimbabwe                115            4.610         0.04290
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Afghanistan                   0.31982  0.30285                   0.30335
# ...

# %%
g.describe()
# Out:
#             Happiness Rank                                                \
#                      count   mean std    min    25%    50%    75%    max
# Country
# Afghanistan            1.0  153.0 NaN  153.0  153.0  153.0  153.0  153.0
# Albania                1.0   95.0 NaN   95.0   95.0   95.0   95.0   95.0
# Algeria                1.0   68.0 NaN   68.0   68.0   68.0   68.0   68.0
# Angola                 1.0  137.0 NaN  137.0  137.0  137.0  137.0  137.0
# Argentina              1.0   30.0 NaN   30.0   30.0   30.0   30.0   30.0
# ...                    ...    ...  ..    ...    ...    ...    ...    ...
# Venezuela              1.0   23.0 NaN   23.0   23.0   23.0   23.0   23.0
# Vietnam                1.0   75.0 NaN   75.0   75.0   75.0   75.0   75.0
# Yemen                  1.0  136.0 NaN  136.0  136.0  136.0  136.0  136.0
# Zambia                 1.0   85.0 NaN   85.0   85.0   85.0   85.0   85.0
# Zimbabwe               1.0  115.0 NaN  115.0  115.0  115.0  115.0  115.0
#
# ...

# %%
# %matplotlib inline
g.plot()
# Out:
# C:\Users\emman\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1085: UserWarning: Attempting to set identical left == right == 152.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# C:\Users\emman\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1085: UserWarning: Attempting to set identical left == right == 94.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# C:\Users\emman\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1085: UserWarning: Attempting to set identical left == right == 67.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# C:\Users\emman\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1085: UserWarning: Attempting to set identical left == right == 136.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# ...
